# %% [markdown]
# PPT에 사용하기 좋을듯 https://blog.naver.com/slykid/221646038436
# 내용 설명 https://blog.naver.com/flf503/222626519176
#
# PDF 정리
#
# 결정트리(Decision Tree) : 규칙 노드 생성 프로세스
# 결정트리 장점 : 쉽다/직관적/가공영향도 낮음
# 결정트리 단점
#
# 결정트리 주요 하이퍼 파라미터
#
#
# https://graphviz.org/download/
#     Graphviz 최신 모드 window 64bit 설치
#
#     C:\Program Files\Graphviz\bin
#
#
#     * 이제 환경설정 → 내컴퓨터 우클릭 → 시스템 속성 → 설정 검색 → 환경변수 → 시스템 환경변수 편집 → 환경변수
#
#     * 환경 변수의 user 사용자 변수 Path 더블클릭 → C:\Program Files\Graphviz\bin 새로 만들기
#
#     * 환경 변수의 시스템 변수 Path 더블클릭 →  C:\Program Files\Graphviz\bin\dot.exe 새로 만들기
#
#
# * 주피터 노트북을 키고 있는 프롬프트까지 다 끄고 → 아나콘다 프롬프트를 실행 → pip install graphviz
# * 프롬프트에 dot -version → dot -c 치고 아무것도 안뜨면 완성

# %% [markdown]
# ### 결정 트리(Decision Tree) : 하이퍼 파라미터 & 시각화

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split

# %%
iris_data = load_iris()

#DecisionTreeClassifier 객체 생성

df_clf = DecisionTreeClassifier(random_state = 11)
x_train = iris_data.data
y_train = iris_data.target

# 학습 수행
df_clf.fit(x_train, y_train)
# 예측 수행
pred = df_clf.predict(x_train)

# %%
# export_graphviz()의 호출 결과로 out_file로 지정된 tree.dot 파일을 생성함
export_graphviz(df_clf, out_file ='tree.dot', class_names=iris_data.target_names, 
               feature_names = iris_data.feature_names, impurity=True, filled=True)

# %%
import graphviz

# 위에서 생성된 tree.dot 파일을 Graphviz 읽어서 Jupyter Notebook상에서 시각화
with open("tree.dot") as f :
    dot_graph = f.read()
    
graphviz.Source(dot_graph)
