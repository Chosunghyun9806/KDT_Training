# %%
import pandas as pd

df = pd.read_excel('./생활습관병.xlsx', header = 7, encoding='cp949')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [90], in <cell line: 3>()
#       1 import pandas as pd
# ----> 3 df = pd.read_excel('./생활습관병.xlsx', header = 7, encoding='cp949')
#       4 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_excel() got an unexpected keyword argument 'encoding'

# %%
df = df.set_index(['연령구분10세'])
df
# Out:
#                항목 성별구분     환자수   환자수.1   환자수.2   환자수.3   환자수.4       총합수
# 연령구분10세
# 계        생활습관병_위암    계  158617  164328  165421  161962  165082       NaN
# 소계       생활습관병_위암    남  106764  110751  111301  109061  110831       NaN
# 0_9세     생활습관병_위암    남       2       2       0       0       0       4.0
# 10_19세   생활습관병_위암    남       7       5       5       4       5      26.0
# 20_29세   생활습관병_위암    남      94      95     105      98      89     481.0
# 30_39세   생활습관병_위암    남    1359    1278    1121     985     898    5641.0
# 40_49세   생활습관병_위암    남    8257    8164    7503    6880    6522   37326.0
# 50_59세   생활습관병_위암    남   25694   26001   24835   23164   21930  121624.0
# 60_69세   생활습관병_위암    남   37068   38551   39113   39119   40798  194649.0
# 70_79세   생활습관병_위암    남   29795   31680   32348   32254   33022  159099.0
# 80세이상    생활습관병_위암    남    8697    9673   10595   10866   11765   51596.0
# 소계       생활습관병_위암    여   51853   53577   54120   52901   54251       NaN
# ...

# %%
df_n = pd.pivot_table(df,
                     index = df.index,
                     columns = '성별구분',
                     values = '총합수')
df_n
# Out:
# 성별구분            남        여
# 연령구분10세
# 0_9세          4.0      2.0
# 10_19세       26.0     25.0
# 20_29세      481.0    737.0
# 30_39세     5641.0   7873.0
# 40_49세    37326.0  31784.0
# 50_59세   121624.0  59074.0
# 60_69세   194649.0  73409.0
# 70_79세   159099.0  70079.0
# 80세이상     51596.0  34322.0

# %%
df_n.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='연령구분10세'>

# %%
pat_m = df['총합수'].iloc[2:11]
pat_f = df['총합수'].iloc[12:21]

# %%
print(pat_m)
print(pat_f)
# Out:
# 연령구분10세
# 0_9세           4.0
# 10_19세        26.0
# 20_29세       481.0
# 30_39세      5641.0
# 40_49세     37326.0
# 50_59세    121624.0
# 60_69세    194649.0
# 70_79세    159099.0
# 80세이상      51596.0
# Name: 총합수, dtype: float64
# 연령구분10세
# 0_9세          2.0
# 10_19세       25.0
# 20_29세      737.0
# 30_39세     7873.0
# 40_49세    31784.0
# 50_59세    59074.0
# 60_69세    73409.0
# 70_79세    70079.0
# 80세이상     34322.0
# Name: 총합수, dtype: float64

# %%
pat_m.plot()
# Out:
# <AxesSubplot:xlabel='연령구분10세'>
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.rc('font', family = 'Malgun Gothic')
plt.title('연령별 생활습관병(위암) 환자수')
pat_m.plot(kind='bar')
pat_f.plot(kind='bar')
#plt.bar(pat_m, height=10)
plt.legend()
plt.show()
