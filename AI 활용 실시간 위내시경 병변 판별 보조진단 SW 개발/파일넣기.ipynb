# %%
import csv
import pymysql

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
a = open('./시도별 신규 암유형별 등록인원 현황.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(a))

# %%
for data in csvReader[2:] :
    row1 = data[0]
    row2 = data[1]
    row3 = data[2]
    row4 = data[3]
    row5 = data[4]
    row6 = data[5]
    row7 = data[6]
    row8 = data[7]
    row9 = data[8]
    row10 = data[9]
    row11 = data[10]
    row12 = data[11]
    row13 = data[12]
    row14 = data[13]
    row15 = data[14]
    row16 = data[15]
    row17 = data[16]
    row18 = data[17]
    row19 = data[18]
    row20 = data[19]
    
    print(data)
    sql = """insert into newcantbl values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""
    cur.execute(sql, (row1, row2, row3, row4, row5, row6, row7, row8, row9, row10, row11, row12, row13, row14, row15, row16, row17, row18, row19, row20))
    
a.close()
conn.commit()
# Out:
# ['계', '317988', '60519', '22661', '14418', '16994', '8447', '8540', '6516', '1820', '76733', '10117', '9763', '13608', '12442', '13209', '17709', '20589', '3903', '0']
# ['폐암', '28557', '5059', '2053', '1429', '1460', '699', '734', '544', '146', '6325', '1036', '981', '1466', '1164', '1282', '1974', '1854', '350', '0']
# ['위암', '26994', '4381', '2019', '1218', '1355', '657', '773', '569', '134', '6087', '880', '1046', '1422', '1143', '1173', '1813', '1992', '331', '0']
# ['간암', '17989', '2976', '1514', '745', '927', '499', '400', '402', '67', '3948', '703', '560', '686', '710', '1000', '1120', '1458', '274', '0']
# ['대장암', '27311', '4899', '1986', '1244', '1499', '612', '741', '478', '124', '6631', '1027', '923', '1261', '1090', '1042', '1638', '1727', '387', '0']
# ['유방암', '27565', '5809', '1753', '1222', '1654', '655', '800', '587', '197', '7559', '749', '748', '991', '884', '763', '1300', '1558', '336', '0']
# ...

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
b = open('./지역별 사망원인별 사망자수.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(b))

# %%
for data in csvReader[1:] :
    row1 = data[0]
    row2 = data[1]
    row3 = data[2]
    row4 = data[3]
    row5 = data[4]
    row6 = data[5]
    
    print(data)
    sql = """insert into deathtbl values(%s,%s,%s,%s,%s,%s);"""
    cur.execute(sql, (row1, row2, row3, row4, row5, row6))
    
b.close()
conn.commit()
# Out:
# ['계', '계', '전국', '298820', '295110', '304948']
# ['계', '계', '서울특별시', '45219', '43829', '45522']
# ['계', '계', '부산광역시', '22570', '22260', '22950']
# ['계', '계', '대구광역시', '14070', '13752', '14460']
# ['계', '계', '인천광역시', '15316', '15131', '15689']
# ['계', '계', '광주광역시', '7781', '7635', '7785']
# ['계', '계', '대전광역시', '7403', '7502', '7572']
# ['계', '계', '울산광역시', '5349', '5268', '5302']
# ['계', '계', '세종특별자치시', '1259', '1221', '1317']
# ['계', '계', '경기도', '60050', '60568', '62794']
# ['계', '계', '강원도', '11976', '11906', '12182']
# ['계', '계', '충청북도', '11334', '11363', '11594']
# ['계', '계', '충청남도', '15802', '15596', '16022']
# ['계', '계', '전라북도', '14552', '14525', '14691']
# ['계', '계', '전라남도', '17219', '16787', '17436']
# ['계', '계', '경상북도', '22289', '21703', '22799']
# ['계', '계', '경상남도', '22719', '22105', '22881']
# ['계', '계', '제주도', '3912', '3959', '3952']
# ['계', '남자', '전국', '161187', '160322', '165163']
# ['계', '남자', '서울특별시', '25384', '24859', '25626']
# ...

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
c = open('./result.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(c))

# %%
for data in csvReader[1:] :
    row1 = data[0]
    row2 = data[1]
    row3 = data[2]
    row4 = data[3]
    row5 = data[4]
    row6 = data[5]
    row7 = data[6]
    row8 = data[7]
    row9 = data[8]
    row10 = data[9]
    
    print(data)
    sql = """insert into sumtbl values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""
    cur.execute(sql, (row1, row2, row3, row4, row5, row6, row7, row8, row9, row10))
    
c.close()
conn.commit()
# Out:
# ['경기', '13452', '76733', '6087', '1954', '9107', '14.4', '6.884339816', '0.45249777', '8.425716482']
# ['서울', '9618', '60519', '4381', '2302', '8617', '13.6', '4.178105995', '0.455500104', '7.023209934']
# ['부산', '3356', '22661', '2019', '710', '3656', '5.8', '4.726760563', '0.601609058', '6.198304158']
# ['경남', '3340', '20589', '1992', '432', '6365', '10', '7.731481481', '0.596407186', '3.234721131']
# ['인천', '2951', '16994', '1355', '433', '1406', '2.2', '6.815242494', '0.459166384', '12.08677098']
# ['경북', '2652', '17709', '1813', '270', '4516', '7.1', '9.822222222', '0.683634992', '3.921390611']
# ['대구', '2414', '14418', '1218', '525', '3800', '6', '4.598095238', '0.504556752', '3.794210526']
# ['충남', '2177', '13608', '1422', '195', '3572', '5.6', '11.16410256', '0.653192467', '3.809630459']
# ['전북', '1806', '12442', '1143', '284', '3554', '5.6', '6.35915493', '0.632890365', '3.500844119']
# ...

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
d = open('./지역별 인구 및 인구밀도.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(d))

# %%
for data in csvReader[4:] :
    row1 = data[0]
    row2 = data[1]
    row3 = data[2]
    row4 = data[3]
    row5 = data[4]
    row6 = data[5]
    row7 = data[6]
    row8 = data[7]
    row9 = data[8]
    row10 = data[9]
    row11 = data[10]
    
    print(data)
    sql = """insert into populationtbl values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""
    cur.execute(sql, (row1, row2, row3, row4, row5, row6, row7, row8, row9, row10, row11))
    
d.close()
conn.commit()
# Out:
# ['계', '51362', '512', '51585', '514', '51765', '516', '51836', '516', '51745', '515']
# ['수도권', '25476', '2149', '25660', '2164', '25851', '2179', '26021', '2193', '26054', '2195']
# ['경기', '12786', '1255', '13027', '1279', '13241', '1299', '13452', '1319', '13612', '1335']
# ['서울', '9766', '16136', '9697', '16023', '9657', '15956', '9618', '15891', '9502', '15699']
# ['부산', '3424', '4447', '3403', '4420', '3381', '4391', '3356', '4358', '3327', '4320']
# ['경남', '3339', '317', '3351', '318', '3350', '318', '3340', '317', '3318', '315']
# ['인천', '2924', '2750', '2936', '2761', '2952', '2777', '2951', '2770', '2941', '2758']
# ['경북', '2675', '141', '2675', '141', '2671', '140', '2652', '139', '2641', '139']
# ['대구', '2458', '2782', '2449', '2772', '2437', '2758', '2414', '2733', '2388', '2702']
# ['충남', '2153', '262', '2177', '265', '2189', '265', '2177', '264', '2177', '264']
# ['전북', '1829', '227', '1823', '226', '1812', '225', '1806', '224', '1794', '222']
# ...

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
e = open('./시도별 내시경 전문의 인원수.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(e))

# %%
for data in csvReader[1:] :
    row1 = data[0]
    row2 = data[1]
    
    print(data)
    sql = """insert into endotbl values(%s,%s);"""
    cur.execute(sql, (row1, row2))
    
e.close()
conn.commit()
# Out:
# ['계', '8576']
# ['서울', '2302']
# ['부산', '710']
# ['대구', '525']
# ['인천', '433']
# ['광주', '322']
# ['대전', '292']
# ['울산', '166']
# ['세종', '42']
# ['경기', '1954']
# ['강원', '186']
# ['충북', '177']
# ['충남', '195']
# ['전북', '284']
# ['전남', '213']
# ['경북', '270']
# ['경남', '432']
# ['제주', '73']

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
f = open('./시도별 공공의료기관 기능별병상 수.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(f))

# %%
for data in csvReader[4:]: 
    row1 = data[0]
    row2 = data[1]
    row3 = data[2]
    row4 = data[3]
    row5 = data[4]
    row6 = data[5]
    row7 = data[6]
    row8 = data[7]
    row9 = data[8]
    row10 = data[9]
    row11 = data[10]
    row12 = data[11]
    row13 = data[12]
    row14 = data[13]
    row15 = data[14]
    row16 = data[15]
    row17 = data[16]
    row18 = data[17]
    row19 = data[18]
    row20 = data[19]
    row21 = data[20]
    row22 = data[21]
    row23 = data[22]
    row24 = data[23]
    row25 = data[24]
    row26 = data[25]
    row27 = data[26]
    row28 = data[27]
    row29 = data[28]
    row30 = data[29]
    row31 = data[30]
    row32 = data[31]
    row33 = data[32]
    row34 = data[33]
    row35 = data[34]
    row36 = data[35]
    row37 = data[36]
    row38 = data[37]
    row39 = data[38]
    row40 = data[39]
    row41 = data[40]
    row42 = data[41]
    row43 = data[42]
    row44 = data[43]
    row45 = data[44]
    row46 = data[45]
    row47 = data[46]
    row48 = data[47]
    row49 = data[48]
    row50 = data[49]
    row51 = data[50]
    row52 = data[51]
    row53 = data[52]
    row54 = data[53]
    row55 = data[54]
    row56 = data[55]
    row57 = data[56]
    row58 = data[57]
    row59 = data[58]
    row60 = data[59]
    row61 = data[60]
    row62 = data[61]
    
    print(data)
  
  
    sql = """insert into govtbl values(%s, %s, %s, %s,%s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s,%s, %s
    ,%s, %s, %s, %s,%s, %s, %s, %s,%s, %s,%s, %s, %s, %s,%s, %s, %s, %s,%s, %s,%s, %s, %s, %s,%s, %s, %s, %s,%s, %s,%s,%s);"""
    cur.execute(sql, (row1, row2, row3, row4, row5, row6, row7, row8, row9, row10,
                      row11, row12, row13, row14, row15, row16, row17, row18, row19, row20,
                      row21, row22, row23, row24, row25, row26, row27, row28, row29, row30,
                      row31, row32, row33, row34, row35, row36, row37, row38, row39, row40,
                      row41, row42, row43, row44, row45, row46, row47, row48, row49, row50,
                      row51, row52, row53, row54, row55, row56, row57, row58, row59, row60,
                      row61, row62))
    
f.close()
conn.commit()
# Out:
# ['서울', '_0002', '8553', '13.2', '2270', '14.1', '1939', '17.3', '1348', '11.7', '2111', '18.5', '885', '6.1', '8453', '13.1', '2244', '13.7', '1911', '17.1', '1466', '13.4', '1992', '17.5', '840', '5.8', '8333', '13', '2237', '13.8', '1909', '16.7', '1468', '13.5', '1885', '17.3', '834', '5.7', '8283', '13.3', '2236', '13.9', '1907', '16.8', '1458', '14.6', '1844', '17.9', '838', '5.8', '8617', '13.6', '2257', '13.6', '2241', '18', '1397', '15.1', '1819', '17.6', '903', '6.1']
# ['부산', '_0003', '4117', '6.4', '1331', '8.3', '502', '4.5', '822', '7.1', '607', '5.3', '855', '5.9', '4150', '6.4', '1310', '8', '555', '5', '801', '7.3', '629', '5.5', '855', '5.9', '4009', '6.3', '1211', '7.5', '555', '4.8', '759', '7', '629', '5.8', '855', '5.9', '3957', '6.4', '1194', '7.4', '555', '4.9', '729', '7.3', '629', '6.1', '850', '5.9', '3656', '5.8', '1191', '7.2', '548', '4.4', '499', '5.4', '586', '5.7', '832', '5.6']
# ...

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
g = open('./24개 암종 성별 암발생자수.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(g))

# %%
for data in csvReader[2:]:
    row1 = data[0]
    row2 = data[1]
    row3 = data[2]
    row4 = data[3]
    row5 = data[4]
    row6 = data[5]
    row7 = data[6]
    row8 = data[7]
    row9 = data[8]
    row10 = data[9]
    row11 = data[10]
    row12 = data[11]
    row13 = data[12]
    row14 = data[13]
    row15 = data[14]
    row16 = data[15]
    row17 = data[16]
    row18 = data[17]
    row19 = data[18]
    row20 = data[19]
    row21 = data[20]
    row22 = data[21]
    
    print(data)
  
  
    sql = """insert into 24cantbl values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""
    cur.execute(sql, (row1, row2, row3, row4, row5, row6, row7, row8, row9, row10,
                    row11, row12, row13, row14, row15, row16, row17, row18, row19, row20,
                    row21, row22))

g.close()
conn.commit()
# Out:
# ['모든 암(C00-C96)', '계', '218204', '100', '428.3', '280.4', '232621', '100', '455.1', '291.2', '236190', '100', '461', '287.7', '245874', '100', '479.3', '292.4', '254718', '100', '496.2', '295.8']
# ['모든 암(C00-C96)', '남자', '115103', '100', '452.1', '306', '121866', '100', '477.4', '312.3', '124343', '100', '486.2', '306.7', '129824', '100', '507.1', '308.7', '134180', '100', '523.9', '308.1']
# ['모든 암(C00-C96)', '여자', '103101', '100', '404.4', '270.8', '110755', '100', '432.9', '285.6', '111847', '100', '436', '283.6', '116050', '100', '451.6', '290.8', '120538', '100', '468.5', '297.4']
# ['입술, 구강 및 인두(C00-C14)', '계', '3367', '1.5', '6.6', '4.4', '3607', '1.6', '7.1', '4.6', '3743', '1.6', '7.3', '4.6', '3843', '1.6', '7.5', '4.6', '3969', '1.6', '7.7', '4.6']
# ['입술, 구강 및 인두(C00-C14)', '남자', '2432', '2.1', '9.6', '6.5', '2569', '2.1', '10.1', '6.8', '2677', '2.2', '10.5', '6.8', '2766', '2.1', '10.8', '6.7', '2863', '2.1', '11.2', '6.8']
# ...

# %%
conn = pymysql.connect(host='localhost', user='root', password='1111', db='wecs', charset='utf8')
cur = conn.cursor()

# %%
h = open('./시군구별 전문과목별 전문의 인력현황.csv', 'r', encoding = 'cp949')
csvReader = list(csv.reader(h))

# %%
for data in csvReader[2:]: # csv 파일에 column명이 있다면 csvReader[1:]로 설정하고 하면 된다.
    row1 = data[0]
    row2 = data[1]
    row3 = data[2]
    row4 = data[3]
    row5 = data[4]
    row6 = data[5]
    row7 = data[6]
    row8 = data[7]
    row9 = data[8]
    row10 = data[9]
    row11 = data[10]
    row12 = data[11]
    row13 = data[12]
    row14 = data[13]
    row15 = data[14]
    row16 = data[15]
    row17 = data[16]
    row18 = data[17]
    row19 = data[18]
    row20 = data[19]
    row21 = data[20]
    row22 = data[21]
    row23 = data[22]
    row24 = data[23]
    row25 = data[24]
    row26 = data[25]
    row27 = data[26]
    row28 = data[27]
    
    print(data)
  
  
    sql = """insert into propoptbl values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""
    cur.execute(sql, (row1, row2, row3, row4, row5, row6, row7, row8, row9, row10,
                     row11, row12, row13, row14, row15, row16, row17, row18, row19, row20,
                     row21, row22, row23, row24, row25, row26, row27, row28))

h.close()
conn.commit()
# Out:
# ['전체', '88877', '16921', '1953', '3794', '6275', '6574', '2913', '1140', '2126', '4888', '5906', '5840', '3510', '3977', '2290', '2610', '3910', '321', '885', '907', '57', '2235', '247', '6935', '1913', '560', '190']
# ['서울', '24290', '4623', '518', '955', '1515', '1564', '663', '306', '1080', '1436', '1548', '1260', '1072', '1091', '878', '705', '1317', '120', '318', '276', '18', '577', '91', '1844', '387', '82', '46']
# ['부산', '6835', '1412', '148', '298', '502', '527', '219', '84', '164', '366', '455', '417', '298', '321', '157', '194', '269', '28', '70', '66', '3', '165', '21', '510', '89', '40', '12']
# ['대구', '4953', '985', '144', '196', '367', '362', '176', '52', '131', '261', '333', '332', '222', '216', '129', '158', '195', '20', '56', '50', '1', '114', '21', '338', '58', '19', '17']
# ['인천', '4349', '850', '86', '173', '318', '357', '166', '55', '64', '217', '296', '298', '164', '200', '92', '132', '152', '14', '38', '48', '2', '116', '10', '318', '131', '47', '5']
# ...
