# %%
import random
import glob
import os
import shutil
import itertools
import numpy as np
import json
import cv2
import matplotlib.pyplot as plt

# %%
dir_ = './OCR_Hack/sum_data/images_reshape'
save_dir = './OCR_Hack/sum_data/test/images/'
output = glob.glob(dir_ + '/*.jpg')

# %%
output[0]
# Out:
# './OCR_Hack/sum_data/images_reshape\\000000000028637_005.jpg'

# %%
output[0].split('\\')[1]
# Out:
# '000000000028637_005.jpg'

# %%
len(output)
# Out:
# 11683

# %%
x = random.sample(range(0,len(output)), 300)

# %%
x
# Out:
# [10816,
#  6044,
#  158,
#  10067,
#  7716,
#  9022,
#  6254,
#  9176,
#  11012,
#  7719,
#  9437,
#  8742,
#  1672,
#  1169,
#  1145,
#  8029,
#  9060,
#  5029,
#  2755,
#  532,
#  8733,
#  1673,
#  947,
#  24,
#  2998,
#  6158,
#  11342,
#  2252,
#  1355,
#  2426,
#  2905,
#  5670,
#  6303,
#  9420,
#  759,
#  4002,
#  7861,
#  11178,
#  4849,
#  10223,
#  5246,
#  6378,
#  6598,
#  152,
#  7278,
#  248,
#  5792,
#  1950,
#  10754,
#  6775,
#  4454,
#  7420,
#  4247,
#  4856,
#  5730,
#  9259,
#  10477,
#  3223,
#  9510,
#  6760,
#  6352,
#  10811,
#  3689,
#  5742,
#  10127,
#  1445,
#  3158,
#  168,
#  5224,
#  1424,
#  2986,
#  3548,
#  1467,
#  7201,
#  5780,
#  8985,
#  3172,
#  6766,
#  8642,
#  2115,
#  8859,
#  2164,
#  2668,
#  7369,
#  9483,
#  8428,
#  7217,
#  8489,
#  5642,
#  8184,
#  5217,
#  8509,
#  2699,
#  6811,
#  5071,
#  11554,
#  1912,
#  9508,
#  9290,
#  5750,
#  5121,
#  5891,
#  11374,
#  2689,
#  6733,
#  4099,
#  4554,
#  1432,
#  3087,
#  8560,
# ...

# %%
dir_img = './OCR_Hack/sum_data/images_reshape/'

# %%
dir_img.split('/')
# Out:
# ['.', 'OCR_Hack', 'sum_data', 'images_reshape', '']

# %%
for i in x:
    filename = output[i].split('\\')[1]
    shutil.move(dir_img + filename, save_dir + filename)
    print(i)
# Out:
# 10816
# 6044
# 158
# 10067
# 7716
# 9022
# 6254
# 9176
# 11012
# 7719
# 9437
# 8742
# 1672
# 1169
# 1145
# 8029
# 9060
# 5029
# 2755
# 532
# 8733
# 1673
# 947
# 24
# 2998
# 6158
# 11342
# 2252
# 1355
# 2426
# 2905
# 5670
# 6303
# 9420
# 759
# 4002
# 7861
# 11178
# 4849
# 10223
# 5246
# 6378
# 6598
# 152
# 7278
# 248
# 5792
# 1950
# 10754
# 6775
# 4454
# 7420
# 4247
# 4856
# 5730
# 9259
# 10477
